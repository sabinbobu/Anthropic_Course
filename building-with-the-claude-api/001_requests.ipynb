# %%
# Install dependencies

# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "")

# %%
# Create an API client

# from anthropic import Anthropic

# client = Anthropic()
model = "claude-sonnet-4-0"

from openai import OpenAI
client = OpenAI()

# %%
# Make a request

# Anthropic way
# response = client.messages.create(
#     model=model,
#     max_tokens=4096,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence"
#         }
#     ]
# )

# OpenAi way
response = client.responses.create(
    model="gpt-4.1-nano",
    input="What is quantum computing? Answer in one sentence"
)

# %%
# Client - Api interface

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )

# %%
# Anthropic way
# response
# response.content[0].text

print(response.output_text)

response = client.responses.create(
    model="gpt-4.1-nano",
    input="Write another sentance"
)

print(response.output_text)
# Out:
# Quantum computing is a type of computation that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data more efficiently than classical computers for certain problems.
# Sure! Here's another sentence: The gentle breeze whispered through the trees, creating a soothing melody.
