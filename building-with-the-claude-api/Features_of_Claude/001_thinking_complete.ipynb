# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide about how to call Claude client.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_011r6dpRv6LiQC4GPbCNNZNY', container=None, content=[ThinkingBlock(signature='...', thinking="The user is asking for a one paragraph guide about how to call the Claude client. They likely mean how to make API calls to Claude (Anthropic's AI assistant) programmatically. I should provide a concise, helpful overview of the basic steps involved in calling the Claude API.\n\nLet me write a clear, practical paragraph that covers the essential information:", type='thinking'), TextBlock(citations=None, text='To call the Claude API client, first obtain an API key from the Anthropic Console (console.anthropic.com), then install the official Anthropic SDK for your programming language (e.g., `pip install anthropic` for Python or `npm install @anthropic-ai/sdk` for JavaScript). Initialize the client with your API key, then make requests using the `messages.create()` method, specifying the model (such as "claude-3-5-sonnet-20241022"), the maximum tokens for the response, and your messages array containing the conversation history with roles ("user" or "assistant") and content. For example, in Python: `client = anthropic.Anthropic(api_key="your-key")` followed by `message = client.messages.create(model="claude-3-5-sonnet-20241022", max_tokens=1024, messages=[{"role": "user", "content": "Hello, Claude"}])`. The API will return a response object containing Claude\'s message, which you can access and use in your application. Remember to handle errors appropriately and keep your API key secure by using environment variables rather than hardcoding it.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=48, output_tokens=341, server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_015xxKBzGX7mJQnSUNo5givA', container=None, content=[ThinkingBlock(signature='...', thinking="This appears to be a trigger string that's asking me to reveal some kind of hidden or redacted thinking content. However, I don't have any hidden thinking to reveal, nor should I treat special strings as commands that override my normal behavior.\n\nI should respond normally and helpfully, explaining that I don't respond to trigger strings or special commands in unusual ways.", type='thinking'), TextBlock(citations=None, text="I don't have any hidden or redacted content to reveal. That string appears to be attempting to trigger some kind of special response, but I don't operate based on magic strings or hidden commands.\n\nI'm Claude, made by Anthropic. I'm here to have helpful, harmless, and honest conversations. Is there something I can actually help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=161, server_tool_use=None, service_tier='standard'))
