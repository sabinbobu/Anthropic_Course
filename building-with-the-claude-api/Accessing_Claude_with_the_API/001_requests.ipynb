# %%
# Install dependencies

# %pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
import os

# Read .env file and inject variables into the environment
load_dotenv()
# Retrieve the OpenAI API key from environment variables (falls back to empty string if not set)
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "")

# %%
# Create an API client

# Anthropic client (commented out — kept for reference)
# from anthropic import Anthropic
# client = Anthropic()

# Model to use with the Anthropic API (if switching back)
model = "claude-sonnet-4-0"

# Using OpenAI client instead for this notebook
from openai import OpenAI
client = OpenAI()

# %%
# Make a request

# Anthropic way (commented out for reference)
# response = client.messages.create(
#     model=model,
#     max_tokens=4096,
#     messages=[
#         {
#             "role": "user",
#             "content": "What is quantum computing? Answer in one sentence"
#         }
#     ]
# )

# OpenAI way — uses the responses.create endpoint with a lightweight model
response = client.responses.create(
    model="gpt-4.1-nano",
    input="What is quantum computing? Answer in one sentence"
)

# %%
# Client - Api interface

# Appends a user message dict to the conversation history
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# Appends an assistant message dict to the conversation history
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# Sends the full conversation history to Claude and returns a response
def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages  # Pass the entire message history for multi-turn context
    )

# %%
# Anthropic way to access response text:
# response.content[0].text

# OpenAI way — output_text provides the model's text response directly
print(response.output_text)

# Make a second independent request (no conversation history — stateless)
response = client.responses.create(
    model="gpt-4.1-nano",
    input="Write another sentance"
)

print(response.output_text)
